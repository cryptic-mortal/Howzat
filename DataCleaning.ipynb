# %% [markdown]
# # 2008-2011

# %%
import pandas as pd
import numpy as np

# %%
data1=pd.read_csv("ipl_da_08_11.csv")

# %%
data1
# Out:
#      Unnamed: 0   Match Type              POTM         Venue Team1 Team2  \
# 0             0       League  Brendon McCullum     Bengaluru   KKR   RCB
# 1             1       League    Michael Hussey        Mohali   CSK  KXIP
# 2             2       League  Farveez Maharoof         Delhi    RR    DC
# 3             3       League      David Hussey  Eden Gardens   DCH   KKR
# 4             4       League      Mark Boucher      Wankhede    MI   RCB
# ..          ...          ...               ...           ...   ...   ...
# 242         247       League    James Franklin  Eden Gardens   KKR    MI
# 243         248  Qualifier 1      Suresh Raina      Wankhede   RCB   CSK
# 244         249   Eliminator       Munaf Patel      Wankhede   KKR    MI
# 245         250  Qualifier 2       Chris Gayle       Chennai   RCB    MI
# 246         251        Final      Murali Vijay       Chennai   CSK   RCB
#
#                      Toss_Winner Toss_Decision      Winner  Win_Margin  \
# ...

# %%
data1[data1.isna().any(axis=1)==1]
data1.columns
# Out:
# Index(['Unnamed: 0', 'Match Type', 'POTM', 'Venue', 'Team1', 'Team2',
#        'Toss_Winner', 'Toss_Decision', 'Winner', 'Win_Margin', 'Result_Type',
#        'Target_Runs', 'Season', 'Match'],
#       dtype='object')

# %%
data1.loc[68,'Winner']='RR'
data1.loc[68,'Win_Margin']=0
data1.loc[68,'Result_Type']="runs"
data1.loc[68,'Target_Runs']=  150

data1.loc[133,'Winner']="KXIP"
data1.loc[133,'Win_Margin']=0
data1.loc[133,'Result_Type']="runs"
data1.loc[133,'Target_Runs']=  136

# %%
data1=data1.dropna()

# %%
data1.columns
# Out:
# Index(['Unnamed: 0', 'Match Type', 'POTM', 'Venue', 'Team1', 'Team2',
#        'Toss_Winner', 'Toss_Decision', 'Winner', 'Win_Margin', 'Result_Type',
#        'Target_Runs', 'Season', 'Match'],
#       dtype='object')

# %%
data1.info()
data1.drop("Unnamed: 0",axis=1,inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     247 non-null    int64
#  1   Match Type     247 non-null    object
#  2   POTM           247 non-null    object
#  3   Venue          247 non-null    object
#  4   Team1          247 non-null    object
#  5   Team2          247 non-null    object
#  6   Toss_Winner    247 non-null    object
#  7   Toss_Decision  247 non-null    object
#  8   Winner         247 non-null    object
#  9   Win_Margin     247 non-null    int64
#  10  Result_Type    247 non-null    object
#  11  Target_Runs    247 non-null    int64
#  12  Season         247 non-null    int64
#  13  Match          247 non-null    object
# dtypes: int64(4), object(10)
# memory usage: 27.1+ KB

# %%
data1.Match.value_counts()
# Out:
# Match
# ['2nd', 'match']     4
# ['4th', 'match']     4
# ['28th', 'match']    4
# ['5th', 'match']     4
# ['10th', 'match']    4
#                     ..
# ['69th', 'match']    1
# ['70th', 'match']    1
# Qualifier 1          1
# Eliminator           1
# Qualifier 2          1
# Name: count, Length: 98, dtype: int64

# %%
season = [2011]
m_type = ["Qualifier 1", "Eliminator", "Qualifier 2", "Final"]

# %%
data1[data1.Match=="Final"]
season_1=[2008,2009,2010]
ses_8_9=["SemiFinal_1","SemiFinal_2","Final"]
M_type=ses_8_9 + m_type

# %%
data1
# Out:
#       Match Type              POTM         Venue Team1 Team2  \
# 0         League  Brendon McCullum     Bengaluru   KKR   RCB
# 1         League    Michael Hussey        Mohali   CSK  KXIP
# 2         League  Farveez Maharoof         Delhi    RR    DC
# 3         League      David Hussey  Eden Gardens   DCH   KKR
# 4         League      Mark Boucher      Wankhede    MI   RCB
# ..           ...               ...           ...   ...   ...
# 242       League    James Franklin  Eden Gardens   KKR    MI
# 243  Qualifier 1      Suresh Raina      Wankhede   RCB   CSK
# 244   Eliminator       Munaf Patel      Wankhede   KKR    MI
# 245  Qualifier 2       Chris Gayle       Chennai   RCB    MI
# 246        Final      Murali Vijay       Chennai   CSK   RCB
#
#                      Toss_Winner Toss_Decision      Winner  Win_Margin  \
# 0    Royal Challengers Bangalore         field         KKR         140
# 1            Chennai Super Kings           bat         CSK          33
# ...

# %%
data1[data1.Match=="Final"]
# Out:
#     Match Type            POTM         Venue Team1 Team2  \
# 57       Final    Yusuf Pathan      DY Patil   CSK    RR
# 114      Final  Andrew Symonds  Johannesburg   DCH   RCB
# 174      Final    Suresh Raina      DY Patil   CSK    MI
# 246      Final    Murali Vijay       Chennai   CSK   RCB
#
#                      Toss_Winner Toss_Decision    Winner  Win_Margin  \
# 57              Rajasthan Royals         field        RR           3
# 114  Royal Challengers Bangalore         field  Chargers           6
# 174          Chennai Super Kings           bat       CSK          22
# 246          Chennai Super Kings           bat       CSK          58
#
#     Result_Type  Target_Runs  Season  Match
# 57       wicket          163    2008  Final
# 114        runs          143    2009  Final
# 174        runs          168    2010  Final
# 246        runs          205    2011  Final

# %%
for ses in season_1:
  i=0
  m_idx=data1.loc[(data1["Season"]==ses)&(data1["Match"].str.contains("Final"))].index
  for idx in m_idx:
    if i < len(ses_8_9):
            data1.at[idx, "Match"] = ses_8_9[i]
            i += 1

# %%
for ses in season:
  i=0
  m_idx=data1.loc[(data1["Season"]==ses)&(data1["Match"].str.contains("Final"))].index
  for idx in m_idx:
    if i < len(m_type):
            data1.at[idx, "Match"] = m_type[i]
            i += 1

# %%
data1
# Out:
#       Match Type              POTM         Venue Team1 Team2  \
# 0         League  Brendon McCullum     Bengaluru   KKR   RCB
# 1         League    Michael Hussey        Mohali   CSK  KXIP
# 2         League  Farveez Maharoof         Delhi    RR    DC
# 3         League      David Hussey  Eden Gardens   DCH   KKR
# 4         League      Mark Boucher      Wankhede    MI   RCB
# ..           ...               ...           ...   ...   ...
# 242       League    James Franklin  Eden Gardens   KKR    MI
# 243  Qualifier 1      Suresh Raina      Wankhede   RCB   CSK
# 244   Eliminator       Munaf Patel      Wankhede   KKR    MI
# 245  Qualifier 2       Chris Gayle       Chennai   RCB    MI
# 246        Final      Murali Vijay       Chennai   CSK   RCB
#
#                      Toss_Winner Toss_Decision      Winner  Win_Margin  \
# 0    Royal Challengers Bangalore         field         KKR         140
# 1            Chennai Super Kings           bat         CSK          33
# ...

# %%
for j in M_type:
  data1.loc[data1["Match"].str.contains(j,na=False),"Match Type"]=j

# %%
data1
# Out:
#       Match Type              POTM         Venue Team1 Team2  \
# 0         League  Brendon McCullum     Bengaluru   KKR   RCB
# 1         League    Michael Hussey        Mohali   CSK  KXIP
# 2         League  Farveez Maharoof         Delhi    RR    DC
# 3         League      David Hussey  Eden Gardens   DCH   KKR
# 4         League      Mark Boucher      Wankhede    MI   RCB
# ..           ...               ...           ...   ...   ...
# 242       League    James Franklin  Eden Gardens   KKR    MI
# 243  Qualifier 1      Suresh Raina      Wankhede   RCB   CSK
# 244   Eliminator       Munaf Patel      Wankhede   KKR    MI
# 245  Qualifier 2       Chris Gayle       Chennai   RCB    MI
# 246  Qualifier 1      Murali Vijay       Chennai   CSK   RCB
#
#                      Toss_Winner Toss_Decision      Winner  Win_Margin  \
# 0    Royal Challengers Bangalore         field         KKR         140
# 1            Chennai Super Kings           bat         CSK          33
# ...

# %%
data1["Target_Runs"]=data1["Target_Runs"].astype("int")
data1["Win_Margin"]=data1["Win_Margin"].astype("int")
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Match Type     247 non-null    object
#  1   POTM           247 non-null    object
#  2   Venue          247 non-null    object
#  3   Team1          247 non-null    object
#  4   Team2          247 non-null    object
#  5   Toss_Winner    247 non-null    object
#  6   Toss_Decision  247 non-null    object
#  7   Winner         247 non-null    object
#  8   Win_Margin     247 non-null    int64
#  9   Result_Type    247 non-null    object
#  10  Target_Runs    247 non-null    int64
#  11  Season         247 non-null    int64
#  12  Match          247 non-null    object
# dtypes: int64(3), object(10)
# memory usage: 25.2+ KB

# %%
import os
folder_name="Cleaned_Data"
os.makedirs(folder_name,exist_ok=True)
data1.to_csv(os.path.join(folder_name, "ip_da_08_11_Clean.csv"), index=False)

# %% [markdown]
# # 2012-2015

# %%
data2=pd.read_csv("2012-2015.csv")
data2
# Out:
#      Unnamed: 0   Match Type                  POTM  \
# 0             0       League          Richard Levi
# 1             1       League          Irfan Pathan
# 2             2       League          Steven Smith
# 3             3       League        Ajinkya Rahane
# 4             4       League        AB de Villiers
# ..          ...          ...                   ...
# 267         267       League  Mitchell McClenaghan
# 268         268  Qualifier 1        Kieron Pollard
# 269         269   Eliminator        AB de Villiers
# 270         270  Qualifier 2          Ashish Nehra
# 271         271        Final          Rohit Sharma
#
#                                                  Venue  \
# 0             MA Chidambaram Stadium, Chepauk, Chennai
# 1                                Eden Gardens, Kolkata
# 2                             Wankhede Stadium, Mumbai
# 3                       Sawai Mansingh Stadium, Jaipur
# 4                     M Chinnaswamy Stadium, Bangalore
# ...

# %%
data2.isnull().sum()

data2.drop("Unnamed: 0",axis=1,inplace=True)

# %%
m_type=data2["Match Type"].unique()
m_type=np.delete(m_type,0)
m_type
# Out:
# array(['Qualifier 1', 'Eliminator', 'Qualifier 2', 'Final'], dtype=object)

# %%
data=pd.read_csv("2012-2015.csv")
data.sample(2)
# Out:
#      Unnamed: 0 Match Type          POTM                             Venue  \
# 265         265     League  Shane Watson         Brabourne Stadium, Mumbai
# 51           51     League  Shane Watson  Subrata Roy Sahara Stadium, Pune
#
#                 Team1                  Team2       Toss_Winner Toss_Decision  \
# 265  Rajasthan Royals  Kolkata Knight Riders  Rajasthan Royals     Bat first
# 51      Pune Warriors       Rajasthan Royals     Pune Warriors     Bat first
#
#     Winner   Win_Margin Result_Type Target_Runs  Match  Season
# 265    RR        9 runs        Runs         200     54    2015
# 51     RR    7 wickets      Wickets         126     52    2012

# %%
data["Win_Margin"]=data["Win_Margin"].str.split().str[0]

# %%
data
# Out:
#      Unnamed: 0   Match Type                  POTM  \
# 0             0       League          Richard Levi
# 1             1       League          Irfan Pathan
# 2             2       League          Steven Smith
# 3             3       League        Ajinkya Rahane
# 4             4       League        AB de Villiers
# ..          ...          ...                   ...
# 267         267       League  Mitchell McClenaghan
# 268         268  Qualifier 1        Kieron Pollard
# 269         269   Eliminator        AB de Villiers
# 270         270  Qualifier 2          Ashish Nehra
# 271         271        Final          Rohit Sharma
#
#                                                  Venue  \
# 0             MA Chidambaram Stadium, Chepauk, Chennai
# 1                                Eden Gardens, Kolkata
# 2                             Wankhede Stadium, Mumbai
# 3                       Sawai Mansingh Stadium, Jaipur
# 4                     M Chinnaswamy Stadium, Bangalore
# ...

# %%
match_count = 0

for i in range(data2.shape[0]): 
    for j in m_type: 
        if j in str(data2.iloc[i]["Match Type"]): 
            match_count += 1

print("Total Matches Found:", match_count)
# Out:
# Total Matches Found: 16

# %%
import os
folder_name="Cleaned_Data"
os.makedirs(folder_name,exist_ok=True)
data2.to_csv(os.path.join(folder_name, "2012-2015_Clean.csv"), index=False)

# %% [markdown]
# # 2016 - 2020

# %%
data3=pd.read_csv("data_2016-2020.csv")

# %%
data3.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'index', 'Match Type', 'POTM', 'Venue',
#        'Team1', 'Team2', 'Toss_Winner', 'Toss_Decision', 'Winner',
#        'Win_Margin', 'Result_Type', 'Target_Runs', 'Season', 'Match'],
#       dtype='object')

# %%
data3.drop(["Unnamed: 0.1","Unnamed: 0"],axis=1,inplace=True)
data3
# Out:
#      index   Match Type             POTM         Venue Team1 Team2  \
# 0        0       League   Ajinkya Rahane      Wankhede    MI   RPS
# 1        1       League    Andre Russell  Eden Gardens    DC   KKR
# 2        2       League      Aaron Finch        Mohali  KXIP    GL
# 3        3       League   AB de Villiers     Bengaluru   RCB   SRH
# 4        4       League     Rohit Sharma  Eden Gardens   KKR    MI
# ..     ...          ...              ...           ...   ...   ...
# 295     55       League   Shahbaz Nadeem       Sharjah    MI   SRH
# 296     56  Qualifier 1   Jasprit Bumrah  Dubai (DICS)    MI    DC
# 297     57   Eliminator  Kane Williamson     Abu Dhabi   RCB   SRH
# 298     58  Qualifier 2   Marcus Stoinis     Abu Dhabi    DC   SRH
# 299     59        Final      Trent Boult  Dubai (DICS)    DC    MI
#
#                Toss_Winner Toss_Decision       Winner  Win_Margin Result_Type  \
# 0           Mumbai Indians           bat  Supergiants         9.0      wicket
# ...

# %%
data3.isnull().sum()
# Out:
# index            0
# Match Type       0
# POTM             0
# Venue            0
# Team1            0
# Team2            0
# Toss_Winner      0
# Toss_Decision    0
# Winner           0
# Win_Margin       0
# Result_Type      0
# Target_Runs      0
# Season           0
# Match            0
# dtype: int64

# %%
data3[data3.isnull().any(axis=1)==1]
# Out:
# Empty DataFrame
# Columns: [index, Match Type, POTM, Venue, Team1, Team2, Toss_Winner, Toss_Decision, Winner, Win_Margin, Result_Type, Target_Runs, Season, Match]
# Index: []

# %%
data3.loc[228, 'Match Type'] = "League"
data3.loc[228, 'POTM'] = "Andre Russell"
data3.loc[228, 'Venue'] = "Eden Gardens"
data3.loc[228, 'Team1'] = "KKR"
data3.loc[228, 'Team2'] = "MI"
data3.loc[228, 'Toss_Winner'] = "MI"
data3.loc[228, 'Toss_Decision'] = "Field"
data3.loc[228, 'Winner'] = "KKR"
data3.loc[228, 'Win_Margin'] = 34
data3.loc[228, 'Result_Type'] = "Runs"
data3.loc[228, 'Target_Runs'] = 233
data3.loc[228, 'Season'] = 2019
data3.loc[228, 'Match'] = "47th Match"

data3.loc[88, 'Match Type'] = "League"
data3.loc[88, 'POTM'] = "Nathan Coulter-Nile"
data3.loc[88, 'Venue'] = "Eden Gardens"
data3.loc[88, 'Team1'] = "KKR"
data3.loc[88, 'Team2'] = "RCB"
data3.loc[88, 'Toss_Winner'] = "RCB"
data3.loc[88, 'Toss_Decision'] = "Field"
data3.loc[88, 'Winner'] = "KKR"
data3.loc[88, 'Win_Margin'] = 82
data3.loc[88, 'Result_Type'] = "Runs"
data3.loc[88, 'Target_Runs'] = 132
data3.loc[88, 'Season'] = 2017
data3.loc[88, 'Match'] = "27th Match"

# %%
data3.loc[94,"Win_Margin"]=0
data3.loc[94,"Target_Runs"]=153
data3.loc[94,"Winner"]="MI"

data3.loc[189,"Win_Margin"]=0
data3.loc[189,"Target_Runs"]=185
data3.loc[189,"Winner"]="DC"

data3.loc[230,"Win_Margin"]=0
data3.loc[230,"Target_Runs"]=162
data3.loc[230,"Winner"]="MI"

data3.loc[241,"Win_Margin"]=0
data3.loc[241,"Target_Runs"]=157
data3.loc[241,"Winner"]="DC"

data3.loc[249,"Win_Margin"]=0
data3.loc[249,"Target_Runs"]=201
data3.loc[249,"Winner"]="RCB"

data3.loc[274,"Win_Margin"]=0
data3.loc[274,"Target_Runs"]=1
data3.loc[274,"Winner"]="KKR"

# %%
data3.isnull().sum()
# Out:
# index            0
# Match Type       0
# POTM             0
# Venue            0
# Team1            0
# Team2            0
# Toss_Winner      0
# Toss_Decision    0
# Winner           0
# Win_Margin       0
# Result_Type      0
# Target_Runs      0
# Season           0
# Match            0
# dtype: int64

# %%
data3
# Out:
#      index   Match Type             POTM         Venue Team1 Team2  \
# 0        0       League   Ajinkya Rahane      Wankhede    MI   RPS
# 1        1       League    Andre Russell  Eden Gardens    DC   KKR
# 2        2       League      Aaron Finch        Mohali  KXIP    GL
# 3        3       League   AB de Villiers     Bengaluru   RCB   SRH
# 4        4       League     Rohit Sharma  Eden Gardens   KKR    MI
# ..     ...          ...              ...           ...   ...   ...
# 295     55       League   Shahbaz Nadeem       Sharjah    MI   SRH
# 296     56  Qualifier 1   Jasprit Bumrah  Dubai (DICS)    MI    DC
# 297     57   Eliminator  Kane Williamson     Abu Dhabi   RCB   SRH
# 298     58  Qualifier 2   Marcus Stoinis     Abu Dhabi    DC   SRH
# 299     59        Final      Trent Boult  Dubai (DICS)    DC    MI
#
#                Toss_Winner Toss_Decision       Winner  Win_Margin Result_Type  \
# 0           Mumbai Indians           bat  Supergiants         9.0      wicket
# ...

# %%
data3
# Out:
#      index   Match Type             POTM         Venue Team1 Team2  \
# 0        0       League   Ajinkya Rahane      Wankhede    MI   RPS
# 1        1       League    Andre Russell  Eden Gardens    DC   KKR
# 2        2       League      Aaron Finch        Mohali  KXIP    GL
# 3        3       League   AB de Villiers     Bengaluru   RCB   SRH
# 4        4       League     Rohit Sharma  Eden Gardens   KKR    MI
# ..     ...          ...              ...           ...   ...   ...
# 295     55       League   Shahbaz Nadeem       Sharjah    MI   SRH
# 296     56  Qualifier 1   Jasprit Bumrah  Dubai (DICS)    MI    DC
# 297     57   Eliminator  Kane Williamson     Abu Dhabi   RCB   SRH
# 298     58  Qualifier 2   Marcus Stoinis     Abu Dhabi    DC   SRH
# 299     59        Final      Trent Boult  Dubai (DICS)    DC    MI
#
#                Toss_Winner Toss_Decision       Winner  Win_Margin Result_Type  \
# 0           Mumbai Indians           bat  Supergiants         9.0      wicket
# ...

# %%
match_count = 0

for i in range(data3.shape[0]): 
    for j in m_type: 
        if j in str(data3.iloc[i]["Match Type"]): 
            match_count += 1

print("Total Matches Found:", match_count)
# Out:
# Total Matches Found: 20

# %%
import os
folder_name="Cleaned_Data"
os.makedirs(folder_name,exist_ok=True)
data3.to_csv(os.path.join(folder_name, "data_2016-2020_Clean.csv"), index=False)

# %% [markdown]
# # Data Cleaning on 2021-2024

# %%
data=pd.read_csv("Season_2021-2024.csv")

# %%
data
# Out:
#      Unnamed: 0.1  Unnamed: 0       Match Type                 POTM  \
# 0               0           0       League (N)        Harshal Patel
# 1               1           1       League (N)       Shikhar Dhawan
# 2               2           2       League (N)          Nitish Rana
# 3               3           3       League (N)         Sanju Samson
# 4               4           4       League (N)         Rahul Chahar
# ..            ...         ...              ...                  ...
# 273           273         273       League (N)      Abhishek Sharma
# 274           274         274  Qualifier 1 (N)       Mitchell Starc
# 275           275         275   Eliminator (N)  Ravichandran Ashwin
# 276           276         276  Qualifier 2 (N)        Shahbaz Ahmed
# 277           277         277        Final (N)       Mitchell Starc
#
#           Venue                        Team1                        Team2  \
# 0       Chennai               Mumbai Indians  Royal Challengers Bangalore
# ...

# %%
data['Match Type'] = data['Match Type'].str.replace(' \(N\)', '', regex=True)
data
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\('
# <>:1: SyntaxWarning: invalid escape sequence '\('
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_42000\4039873511.py:1: SyntaxWarning: invalid escape sequence '\('
#   data['Match Type'] = data['Match Type'].str.replace(' \(N\)', '', regex=True)
#      Unnamed: 0.1  Unnamed: 0   Match Type                 POTM       Venue  \
# 0               0           0       League        Harshal Patel     Chennai
# 1               1           1       League       Shikhar Dhawan    Wankhede
# 2               2           2       League          Nitish Rana     Chennai
# 3               3           3       League         Sanju Samson    Wankhede
# 4               4           4       League         Rahul Chahar     Chennai
# ..            ...         ...          ...                  ...         ...
# 273           273         273       League      Abhishek Sharma   Hyderabad
# ...

# %%
match_count = 0

for i in range(data.shape[0]): 
    for j in m_type: 
        if j in str(data.iloc[i]["Match Type"]): 
            match_count += 1

print("Total Matches Found:", match_count)

data.columns
data.drop(["Unnamed: 0.1","Unnamed: 0"],axis=1,inplace=True)
# Out:
# Total Matches Found: 16

# %%
import os
folder_name="Cleaned_Data"
os.makedirs(folder_name,exist_ok=True)
data.to_csv(os.path.join(folder_name, "Season_2021-2024_Clean.csv"), index=False)
